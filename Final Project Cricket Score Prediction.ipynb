# %%
import pandas as pd 
import pickle

# %%
df = pd.read_csv("T20 International Dataset.csv")

# %%
df
# Out:
#         Unnamed: 0  powerPlay  AverageScore  battingTeam  bowlingTeam  \
# 0               29          1         159.2  West Indies        India
# 1               30          1         159.2  West Indies        India
# 2               31          1         159.2  West Indies        India
# 3               32          1         159.2  West Indies        India
# 4               33          1         159.2  West Indies        India
# ...            ...        ...           ...          ...          ...
# 131619      175279          0         130.0  Netherlands  Afghanistan
# 131620      175280          0         130.0  Netherlands  Afghanistan
# 131621      175281          0         130.0  Netherlands  Afghanistan
# 131622      175282          0         130.0  Netherlands  Afghanistan
# 131623      175283          0         130.0  Netherlands  Afghanistan
#
#               city  delivery_left  score  CurrentRunRate  wicketsLeft  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 131624 entries, 0 to 131623
# Data columns (total 14 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Unnamed: 0        131624 non-null  int64
#  1   powerPlay         131624 non-null  int64
#  2   AverageScore      131624 non-null  float64
#  3   battingTeam       131624 non-null  object
#  4   bowlingTeam       131624 non-null  object
#  5   city              131624 non-null  object
#  6   delivery_left     131624 non-null  int64
#  7   score             131624 non-null  int64
#  8   CurrentRunRate    131624 non-null  float64
#  9   wicketsLeft       131624 non-null  int64
#  10  Run_In_Last5      131624 non-null  int64
#  11  Wickets_In_Last5  131624 non-null  int64
#  12  Final_Score       131624 non-null  int64
#  13  innings           131624 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 14.1+ MB

# %%
df.isnull().sum()
# Out:
# Unnamed: 0          0
# powerPlay           0
# AverageScore        0
# battingTeam         0
# bowlingTeam         0
# city                0
# delivery_left       0
# score               0
# CurrentRunRate      0
# wicketsLeft         0
# Run_In_Last5        0
# Wickets_In_Last5    0
# Final_Score         0
# innings             0
# dtype: int64

# %%
df
# Out:
#         Unnamed: 0  powerPlay  AverageScore  battingTeam  bowlingTeam  \
# 0               29          1         159.2  West Indies        India
# 1               30          1         159.2  West Indies        India
# 2               31          1         159.2  West Indies        India
# 3               32          1         159.2  West Indies        India
# 4               33          1         159.2  West Indies        India
# ...            ...        ...           ...          ...          ...
# 131619      175279          0         130.0  Netherlands  Afghanistan
# 131620      175280          0         130.0  Netherlands  Afghanistan
# 131621      175281          0         130.0  Netherlands  Afghanistan
# 131622      175282          0         130.0  Netherlands  Afghanistan
# 131623      175283          0         130.0  Netherlands  Afghanistan
#
#               city  delivery_left  score  CurrentRunRate  wicketsLeft  \
# ...

# %%
#eligible_cities = df['city'].value_counts()[df['city'].value_counts() >= 840].index.tolist()

# %%
#df = df[df['city'].isin(eligible_cities)]

# %%
df
# Out:
#         Unnamed: 0  powerPlay  AverageScore  battingTeam  bowlingTeam  \
# 0               29          1         159.2  West Indies        India
# 1               30          1         159.2  West Indies        India
# 2               31          1         159.2  West Indies        India
# 3               32          1         159.2  West Indies        India
# 4               33          1         159.2  West Indies        India
# ...            ...        ...           ...          ...          ...
# 131619      175279          0         130.0  Netherlands  Afghanistan
# 131620      175280          0         130.0  Netherlands  Afghanistan
# 131621      175281          0         130.0  Netherlands  Afghanistan
# 131622      175282          0         130.0  Netherlands  Afghanistan
# 131623      175283          0         130.0  Netherlands  Afghanistan
#
#               city  delivery_left  score  CurrentRunRate  wicketsLeft  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 131624 entries, 0 to 131623
# Data columns (total 14 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Unnamed: 0        131624 non-null  int64
#  1   powerPlay         131624 non-null  int64
#  2   AverageScore      131624 non-null  float64
#  3   battingTeam       131624 non-null  object
#  4   bowlingTeam       131624 non-null  object
#  5   city              131624 non-null  object
#  6   delivery_left     131624 non-null  int64
#  7   score             131624 non-null  int64
#  8   CurrentRunRate    131624 non-null  float64
#  9   wicketsLeft       131624 non-null  int64
#  10  Run_In_Last5      131624 non-null  int64
#  11  Wickets_In_Last5  131624 non-null  int64
#  12  Final_Score       131624 non-null  int64
#  13  innings           131624 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 14.1+ MB

# %%
df.drop(df.loc[df['innings']==2].index,inplace=True)

# %%
cols_to_remove = ['innings','powerPlay','AverageScore', 'Wickets_In_Last5','city']
df.drop(labels=cols_to_remove , axis=1 , inplace = True)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0        0
# battingTeam       0
# bowlingTeam       0
# delivery_left     0
# score             0
# CurrentRunRate    0
# wicketsLeft       0
# Run_In_Last5      0
# Final_Score       0
# dtype: int64

# %%
df
# Out:
#        Unnamed: 0  battingTeam  bowlingTeam  delivery_left  score  \
# 0              29  West Indies        India             92     28
# 1              30  West Indies        India             91     28
# 2              31  West Indies        India             90     28
# 3              32  West Indies        India             89     28
# 4              33  West Indies        India             88     29
# ...           ...          ...          ...            ...    ...
# 69962       91959  Afghanistan  Netherlands              4    149
# 69963       91960  Afghanistan  Netherlands              3    155
# 69964       91961  Afghanistan  Netherlands              2    156
# 69965       91962  Afghanistan  Netherlands              1    156
# 69966       91963  Afghanistan  Netherlands              0    162
#
#        CurrentRunRate  wicketsLeft  Run_In_Last5  Final_Score
# 0            6.000000            7            28           95
# ...

# %%
df.shape
# Out:
# (69967, 9)

# %%
df['battingTeam'].unique()
# Out:
# array(['West Indies', 'New Zealand', 'Bangladesh', 'India', 'Sri Lanka',
#        'Pakistan', 'Afghanistan', 'Australia', 'England', 'South Africa',
#        'Ireland', 'Netherlands', 'Zimbabwe'], dtype=object)

# %%
df['bowlingTeam'].unique()
# Out:
# array(['India', 'Sri Lanka', 'New Zealand', 'West Indies', 'Australia',
#        'England', 'South Africa', 'Bangladesh', 'Pakistan', 'Ireland',
#        'Zimbabwe', 'Afghanistan', 'Netherlands'], dtype=object)

# %%
total_teams = ['India', 'Sri Lanka', 'New Zealand', 'West Indies', 'Australia',
       'England', 'South Africa', 'Bangladesh', 'Pakistan', 'Ireland',
       'Zimbabwe', 'Afghanistan', 'Netherlands']

# %%
df = df[(df['battingTeam'].isin(total_teams)) & (df['bowlingTeam'].isin(total_teams))]

# %%
print(df['battingTeam'].unique())
print(df['bowlingTeam'].unique())
# Out:
# ['West Indies' 'New Zealand' 'Bangladesh' 'India' 'Sri Lanka' 'Pakistan'
#  'Afghanistan' 'Australia' 'England' 'South Africa' 'Ireland'
#  'Netherlands' 'Zimbabwe']
# ['India' 'Sri Lanka' 'New Zealand' 'West Indies' 'Australia' 'England'
#  'South Africa' 'Bangladesh' 'Pakistan' 'Ireland' 'Zimbabwe' 'Afghanistan'
#  'Netherlands']

# %%
df = df[df['delivery_left']<=84]

# %%
#df.drop(df.loc[df['city']=='Barbados'].index,inplace=True)
#df.drop(df.loc[df['city']=='Ahemdabad'].index,inplace=True)
#df.drop(df.loc[df['city']=='Adelaide'].index,inplace=True)
#df.drop(df.loc[df['city']=='Auckland'].index,inplace=True)

# %%
df
# Out:
#        Unnamed: 0  battingTeam  bowlingTeam  delivery_left  score  \
# 8              37  West Indies        India             84     33
# 9              38  West Indies        India             83     33
# 10             39  West Indies        India             82     33
# 11             40  West Indies        India             81     33
# 12             41  West Indies        India             80     33
# ...           ...          ...          ...            ...    ...
# 69962       91959  Afghanistan  Netherlands              4    149
# 69963       91960  Afghanistan  Netherlands              3    155
# 69964       91961  Afghanistan  Netherlands              2    156
# 69965       91962  Afghanistan  Netherlands              1    156
# 69966       91963  Afghanistan  Netherlands              0    162
#
#        CurrentRunRate  wicketsLeft  Run_In_Last5  Final_Score
# 8            5.500000            5            27           95
# ...

# %%
cat_df = pd.get_dummies(data = df, columns = ['battingTeam' , 'bowlingTeam'])

# %%
cat_df
# Out:
#        Unnamed: 0  delivery_left  score  CurrentRunRate  wicketsLeft  \
# 8              37             84     33        5.500000            5
# 9              38             83     33        5.351351            5
# 10             39             82     33        5.210526            5
# 11             40             81     33        5.076923            5
# 12             41             80     33        4.950000            5
# ...           ...            ...    ...             ...          ...
# 69962       91959              4    149        7.706897            4
# 69963       91960              3    155        7.948718            4
# 69964       91961              2    156        7.932203            4
# 69965       91962              1    156        7.865546            3
# 69966       91963              0    162        8.100000            3
#
#        Run_In_Last5  Final_Score  battingTeam_Afghanistan  \
# 8                27           95                        0
# ...

# %%
#df['city'].unique()

# %%
X = cat_df.drop(columns=['Final_Score'])
Y = cat_df['Final_Score']
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.3,random_state=1)

# %%
X_test
# Out:
#        Unnamed: 0  delivery_left  score  CurrentRunRate  wicketsLeft  \
# 61560       80889             60     65        6.500000            6
# 65195       85713             61     74        7.525424            8
# 41301       54150             74     53        6.913043            8
# 20696       27105             41     97        7.367089            8
# 28809       37712             19    154        9.148515            8
# ...           ...            ...    ...             ...          ...
# 54186       71079              4    195       10.086207            6
# 9938        13012             23    111        6.865979            6
# 35552       46574             59     97        9.540984           10
# 53229       69832              9    172        9.297297            5
# 36628       47969             16    180       10.384615            4
#
#        Run_In_Last5  battingTeam_Afghanistan  battingTeam_Australia  \
# 61560            35                        0                      0
# ...

# %%
X_train.columns
# Out:
# Index(['Unnamed: 0', 'delivery_left', 'score', 'CurrentRunRate', 'wicketsLeft',
#        'Run_In_Last5', 'battingTeam_Afghanistan', 'battingTeam_Australia',
#        'battingTeam_Bangladesh', 'battingTeam_England', 'battingTeam_India',
#        'battingTeam_Ireland', 'battingTeam_Netherlands',
#        'battingTeam_New Zealand', 'battingTeam_Pakistan',
#        'battingTeam_South Africa', 'battingTeam_Sri Lanka',
#        'battingTeam_West Indies', 'battingTeam_Zimbabwe',
#        'bowlingTeam_Afghanistan', 'bowlingTeam_Australia',
#        'bowlingTeam_Bangladesh', 'bowlingTeam_England', 'bowlingTeam_India',
#        'bowlingTeam_Ireland', 'bowlingTeam_Netherlands',
#        'bowlingTeam_New Zealand', 'bowlingTeam_Pakistan',
#        'bowlingTeam_South Africa', 'bowlingTeam_Sri Lanka',
#        'bowlingTeam_West Indies', 'bowlingTeam_Zimbabwe'],
#       dtype='object')

# %%
X_train
# Out:
#        Unnamed: 0  delivery_left  score  CurrentRunRate  wicketsLeft  \
# 18184       23810             53     74        6.626866            7
# 3987         5234             73     71        9.063830            7
# 45274       59341             38     96        7.024390            7
# 58997       77485             72     72        9.000000           10
# 2521         3304             41     92        6.987342            6
# ...           ...            ...    ...             ...          ...
# 35244       46150             60     89        8.900000            7
# 5629         7369             62     66        6.827586            9
# 13194       17283             57     91        8.666667            8
# 35785       46865             14    139        7.867925            4
# 67775       89105             76     39        5.318182            8
#
#        Run_In_Last5  battingTeam_Afghanistan  battingTeam_Australia  \
# 18184            31                        0                      0
# ...

# %%
print(X_train.shape , Y_train.shape)
print(X_test.shape , Y_test.shape)
# Out:
# (45174, 32) (45174,)
# (19361, 32) (19361,)

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression()

# %%
reg.fit(X_train , Y_train)
# Out:
# LinearRegression()

# %%
prediction = reg.predict(X_test)

# %%
import seaborn as sns
sns.distplot(Y_test-prediction)
# Out:
# C:\Users\My PC\ML Projects\T20_Score_Prediction\env\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Final_Score', ylabel='Density'>

# %%
from sklearn import metrics

# %%
from sklearn import metrics

import numpy as np

# Mean Absolute Error

print('MAE: ', metrics.mean_absolute_error(Y_test , prediction))

# Mean Squared Error

print('MSE: ', metrics.mean_squared_error(Y_test, prediction))

# Root Mean Squared Error

print('RMSE: ', np.sqrt(metrics.mean_squared_error(Y_test, prediction)))
# Out:
# MAE:  13.112057342479499
# MSE:  318.810750345455
# RMSE:  17.855272340276834

# %%
import sklearn as sk

# %%
print(metrics.r2_score(Y_test,prediction))
# Out:
# 0.7043959018314483

# %%
Final_Model = 'Cricket_score_prediction_model.pkl'
pickle.dump(reg , open(Final_Model,'wb'))
